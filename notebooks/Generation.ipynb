# %% [markdown]
# #### Playlist Generation

# %% [markdown]
# Now that we have all of these insights on what fuels a successful playlist, we can use those to create our own 'hopefully viral' playlist. We will do so in a four step process:
#
# 1) We will ask the playlist curator for a genre of which to create a playlist from and we will subset our songs data into only songs from said genre.
#
# 2) We will give each individual song in this arsenal a 'score' for how well it matches these attributes.
#
# 3) We will collect the songs with the highest set of scores into a dataframe and have them as a pool to draw from.
#
# 4) We will randomly select songs from this pool, keeping in mind some of the genre variables we introduced and their performances.

# %% [markdown]
# Our scoring metric itself is affected, as mentioned, by the attributes from our final models. Those attributes are average song popularity, the top song popularity, the percentage of explicit songs, the average artists followers, the number of songs, and numerous interaction terms between genres and artists. In order to consistently make playlists for a given genre, however, only a few of these factors become significant. Since we are creating playlists for one genre at a time, the interaction terms become only relevant in their given genres. For demonstration purposes we will be creating an R&B playlist (so here the only valid interaction term is that with The Weeknd), as well as a Jazz playlist (no interactions), and a pop playlist (including an interaction with Sia). Additionally, the number of songs variable becomes less crucial here since we want to consistently generate playlists with the same number of songs. We'll use 50 since that's where the benefit tops out and is customary for Spotify curated playlists.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.api import OLS
import sklearn.metrics as metrics
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import KFold
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.metrics import r2_score
import plotly
plotly.tools.set_credentials_file(username='cohenk2', api_key='dF6eJ0G0zN5JH3ifD1sH')
import plotly.plotly as py
import plotly.figure_factory as ff
import scipy.stats as stats
import pylab 
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns; sns.set(color_codes=True)
sns.set(style="whitegrid")
# %matplotlib inline
# Out:
# /Users/Trevor/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv("total_info.csv", encoding = 'latin')
del df['Unnamed: 0']

desired_genre = 'r&b'
df = df[df['artist_genres'].str.contains(desired_genre)]
df.head()
# Out:
#                  playlist_id     playlist_name   followers        song_name  \
# 1686  37i9dQZF1DXcBWIGoYBM5M  Today's Top Hits  18123888.0       Plain Jane
# 1687  37i9dQZF1DX0XUsuxWHRQd         RapCaviar   8318573.0       Plain Jane
# 1688  37i9dQZF1DWVstK6FYh8Nw   This Is: Future    267999.0  New Level REMIX
# 1689  37i9dQZF1DX2A29LI7xHn1       Signed XOXO   1302273.0       Plain Jane
# 1690  37i9dQZF1DWY4xHQp97fN6         Get Turnt   3263165.0       Plain Jane
#
#       number_of_artists artist_name               artist_id  popularity  \
# 1686                  1   A$AP Ferg  5dHt1vcEm9qb8fCyLcB3HL          90
# 1687                  1   A$AP Ferg  5dHt1vcEm9qb8fCyLcB3HL          90
# 1688                  4   A$AP Ferg  5dHt1vcEm9qb8fCyLcB3HL          58
# 1689                  1   A$AP Ferg  5dHt1vcEm9qb8fCyLcB3HL          90
# 1690                  1   A$AP Ferg  5dHt1vcEm9qb8fCyLcB3HL          90
#
#       track_number  explicit  duration_ms  \
# 1686             8         1       173600
# 1687             8         1       173600
# 1688             1         1       251194
# 1689             8         1       173600
# 1690             8         1       173600
#
#                                       available_markets  delete  \
# 1686  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...     NaN
# 1687  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...     NaN
# 1688  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...     NaN
# 1689  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...     NaN
# 1690  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...     NaN
#
#      artist_popularity artist_followers  \
# 1686                87           821565
# 1687                87           821565
# 1688                87           821565
# 1689                87           821565
# 1690                87           821565
#
#                                           artist_genres
# 1686  ['dwn trap', 'hip hop', 'indie r&b', 'pop rap'...
# 1687  ['dwn trap', 'hip hop', 'indie r&b', 'pop rap'...
# 1688  ['dwn trap', 'hip hop', 'indie r&b', 'pop rap'...
# 1689  ['dwn trap', 'hip hop', 'indie r&b', 'pop rap'...
# 1690  ['dwn trap', 'hip hop', 'indie r&b', 'pop rap'...

# %%
def song_score(artist, song_pop, explicit, artist_followers):
    score = 1
    score = score*1.2*song_pop
    score = score*.05*artist_followers
    if "The Weeknd" in artist and 'r&b' == desired_genre:
        score = score*1.02
    if "Sia" in artist and 'pop' == desired_genre:
        score = score*1.04
    if song_pop > 95:
        score = score*1.09
    if explicit == 1:
        score = score*1.007
    return(score)

# %% [markdown]
# As aforementioned, we can score our R&B songs weighted the variables accordingly (based on the weighted outputs from our random forest model) - including the bonus on songs from the Weeknd. Below you can see a small subset of what this scoring looks like.

# %%
unique_songs = df['song_name'].unique()
columns = ['song_name','artist_name','score']
score_frame = pd.DataFrame(index=range(0,len(unique_songs)), columns=columns)
for idx,song in enumerate(unique_songs):
    try:
        score_frame.loc[idx]['song_name'] = song
        score_frame.loc[idx]['artist_name'] = df.loc[df['song_name'] == song]['artist_name'].iloc[0]
        this_artist = df.loc[df['song_name'] == song]['artist_name'].iloc[0]
        this_popularity = df.loc[df['song_name'] == song]['popularity'].iloc[0]
        this_explicit = df.loc[df['song_name'] == song]['explicit'].iloc[0]
        this_art_followers = df.loc[df['song_name'] == song]['artist_followers'].iloc[0]
        score_frame.loc[idx]['score'] = song_score(this_artist, this_popularity, this_explicit, this_art_followers)
    except:
        score_frame.loc[idx]['score'] = 0
        pass
score_frame.head()
# Out:
#          song_name artist_name        score
# 0       Plain Jane   A$AP Ferg  4.46751e+06
# 1  New Level REMIX   A$AP Ferg  2.87906e+06
# 2       Work REMIX   A$AP Ferg   3.8222e+06
# 3  Rubber Band Man   A$AP Ferg  3.67328e+06
# 4         Olympian   A$AP Ferg  3.12725e+06

# %% [markdown]
# Our R&B playlist then is as follows:

# %%
score_frame.sort_values('score', ascending = False)
threshold = score_frame['score'].quantile(q = 0.75)
top_songs = score_frame[score_frame['score'] >= threshold]
curated_playlist = top_songs.sample(50)
curated_playlist
# Out:
#                                               song_name         artist_name  \
# 38                                     Don't Wake Me Up         Chris Brown
# 1384  I Be Puttin' On - feat. Wiz Khalifa, French Mo...                Wale
# 552                                   Distance And Time         Alicia Keys
# 202                             I Luv This Shit - Remix       August Alsina
# 979                                            No Limit               Usher
# 279                                    Make Me Like You        Gwen Stefani
# 602                                            Sin City         John Legend
# 615                                          #thatPOWER           will.i.am
# 1038                                          Beautiful  Christina Aguilera
# 1488                                     The First Noel       Mary J. Blige
# 89                                           Sure Thing              Miguel
# 965                                  A Moment Like This      Kelly Clarkson
# 1375                          Bad - Remix feat. Rihanna                Wale
# 1019                                     Drink You Away   Justin Timberlake
# 142                    Dead Wrong (feat. Ty Dolla $ign)          Trey Songz
# 87                                         Arch & Point              Miguel
# 6                                       Nasty (Who Dat)           A$AP Ferg
# 424                                       Touch My Body        Mariah Carey
# 1881                                     Diggin' on You                 TLC
# 207                        Better Man (feat. Rick Ross)       PARTYNEXTDOOR
# 947                Love On The Brain - Don Diablo Remix             Rihanna
# 17                                           Doe-Active           A$AP Ferg
# 520   Out Of My Mind (feat. Nicki Minaj) - feat. Nic...               B.o.B
# 948                                         Sex With Me             Rihanna
# 1047                                          Oh Mother  Christina Aguilera
# 1269                                       I. Pink Toes    Childish Gambino
# 586                            So High - Single Version         John Legend
# 1005                Row The Body (feat. French Montana)           Taio Cruz
# 1492                                        I'm In Love       Mary J. Blige
# 267                                          All I Have      Jennifer Lopez
# 81                        The Thrill - Spotify Sessions              Miguel
# 787                                       Return to Air              Bonobo
# 123                                         Slow Motion          Trey Songz
# 1483                                       Not Gon' Cry       Mary J. Blige
# 1411            Dead And Gone (feat. Justin Timberlake)                T.I.
# 1245                                               Blow               Kesha
# 91                                    All I Want Is You              Miguel
# 1000                                  Love in This Club               Usher
# 1463                                             2 Fine              T-Pain
# 1040    Lady Marmalade - From "Moulin Rouge" Soundtrack  Christina Aguilera
# 1915                                    Cherish the Day                Sade
# 154                                              B.E.D.            Jacquees
# 854              (You Drive Me) Crazy - The Stop Remix!      Britney Spears
# 662                                           Partition          BeyoncÌÄå©
# 25                                  Grass Ain't Greener         Chris Brown
# 950                                    Lost In Paradise             Rihanna
# 438          Lose Control (feat. Ciara & Fat Man Scoop)       Missy Elliott
# 10                                               Shabba           A$AP Ferg
# 653                                         Check On It          BeyoncÌÄå©
# 1595                                                You               Lloyd
#
#             score
# 38    1.97947e+07
# 1384   2.2093e+06
# 552   9.51984e+06
# 202   2.61306e+06
# 979   1.69494e+07
# 279   4.11886e+06
# 602   6.99978e+06
# 615   5.15373e+06
# 1038  8.38635e+06
# 1488  2.18267e+06
# 89    5.22818e+06
# 965    4.6232e+06
# 1375  3.40864e+06
# 1019  1.69851e+07
# 142    7.6262e+06
# 87    2.00533e+06
# 6     3.42509e+06
# 424   6.74932e+06
# 1881  2.31339e+06
# 207   3.67622e+06
# 947   4.56485e+07
# 17    2.28339e+06
# 520   3.89598e+06
# 948   6.24174e+07
# 1047  4.93315e+06
# 1269   8.1217e+06
# 586   8.05698e+06
# 1005  3.87516e+06
# 1492  2.29755e+06
# 267   8.43617e+06
# 81    2.50666e+06
# 787   1.96448e+06
# 123   1.02378e+07
# 1483  2.75706e+06
# 1411  7.48906e+06
# 1245  8.67446e+06
# 91    4.51199e+06
# 1000   1.7646e+07
# 1463  3.64477e+06
# 1040  7.89304e+06
# 1915  2.27073e+06
# 154   2.23687e+06
# 854   9.05175e+06
# 662    3.7594e+07
# 25    2.24645e+07
# 950   4.09905e+07
# 438   2.31457e+06
# 10    3.52437e+06
# 653   2.81431e+07
# 1595  2.12753e+06

# %% [markdown]
# We can repeat the same process for Jazz and Pop. Our Jazz playlist is as follows:

# %%
df = pd.read_csv("total_info.csv", encoding = 'latin')
del df['Unnamed: 0']

desired_genre = 'jazz'
df = df[df['artist_genres'].str.contains(desired_genre)]
df.head()

unique_songs = df['song_name'].unique()
columns = ['song_name','artist_name','score']
score_frame = pd.DataFrame(index=range(0,len(unique_songs)), columns=columns)
for idx,song in enumerate(unique_songs):
    try:
        score_frame.loc[idx]['song_name'] = song
        score_frame.loc[idx]['artist_name'] = df.loc[df['song_name'] == song]['artist_name'].iloc[0]
        this_artist = df.loc[df['song_name'] == song]['artist_name'].iloc[0]
        this_popularity = df.loc[df['song_name'] == song]['popularity'].iloc[0]
        this_explicit = df.loc[df['song_name'] == song]['explicit'].iloc[0]
        this_art_followers = df.loc[df['song_name'] == song]['artist_followers'].iloc[0]
        score_frame.loc[idx]['score'] = song_score(this_artist, this_popularity, this_explicit, this_art_followers)
    except:
        score_frame.loc[idx]['score'] = 0
        pass
    
score_frame.sort_values('score', ascending = False)
threshold = score_frame['score'].quantile(q = 0.75)
top_songs = score_frame[score_frame['score'] >= threshold]
curated_playlist = top_songs.sample(50)
curated_playlist
# Out:
#                                               song_name  \
# 2327                                        The Red One
# 2414                             This Land Is Your Land
# 73                                            Let It Be
# 150                                The Bare Necessities
# 234                                     White Christmas
# 2613                                            Perhaps
# 1987                                           The Fool
# 279                                           Work Song
# 365                                         Eyes Of Man
# 228                                Chatanooga Choo Choo
# 344                                            Know You
# 259   Li'l Liza Jane - Live Version - Newport Jazz F...
# 2525                              Back to Nature - Edit
# 45                                   Love And Happiness
# 346                                        Sleepy Seven
# 58                                         Ain't No Way
# 401                 You Can't Catch Me - Single Version
# 2235      Maiden Voyage / Everything In Its Right Place
# 475                             The Beat Of Black Wings
# 363                                        Jamaica Moon
# 115                               Call Me Irresponsible
# 112                            The Way You Look Tonight
# 3226                                           Vem vet?
# 471                               Come In From The Cold
# 162                                 My Favourite Things
# 268                   Sinnerman - Live In New York/1965
# 2507                                         Black Baby
# 2124                                For Better or Worse
# 278                                             Save Me
# 311                                             Samurai
# 526                                          Drift Away
# 489                                   Shadows And Light
# 451                                       A Case Of You
# 2909                              Where We Used To Live
# 292                                          Four Women
# 191   A Rockin' Good Way (To Mess Around And Fall In...
# 198                     April In Paris - Alternate Take
# 334                                           Recurring
# 595                 So In Love - feat. Anthony Hamilton
# 188                                      Drinking Again
# 616                How Sweet It Is (To Be Loved By You)
# 520                             I Am A Motherless Child
# 295   Nobody Knows You When You're Down And Out - Li...
# 2485                                  Music Takes Me Up
# 483                         The Hissing Of Summer Lawns
# 144                                        It Amazes Me
# 510                                            Fat Mama
# 3161                                   World Looking In
# 2257                                      Learn To Love
# 219                                My Little Brown Book
#
#                        artist_name        score
# 2327                 John Scofield       136927
# 2414  Sharon Jones & The Dap-Kings       348156
# 73                 Aretha Franklin  2.34095e+06
# 150                   Tony Bennett       469550
# 234                    Bing Crosby       138672
# 2613               Oscar D'LeÌÄå_n       301563
# 1987           Fleshgod Apocalypse      94817.2
# 279                    Nina Simone  1.90408e+06
# 365                    Chuck Berry       918435
# 228                   Glenn Miller       221286
# 344                         Bonobo  1.92439e+06
# 259                    Nina Simone  1.45312e+06
# 2525             Nightmares On Wax       375818
# 45                        Al Green       405637
# 346                         Bonobo  1.60366e+06
# 58                 Aretha Franklin  2.29006e+06
# 401                    Chuck Berry       675320
# 2235                Robert Glasper       177583
# 475                  Joni Mitchell       398950
# 363                    Chuck Berry       972460
# 115                   Tony Bennett       516505
# 112                   Tony Bennett       594763
# 3226                   Lisa Ekdahl       187146
# 471                  Joni Mitchell       468332
# 162                   Tony Bennett       704325
# 268                    Nina Simone  2.30494e+06
# 2507          Kruder & Dorfmeister       118841
# 2124                      Keb' Mo'       169678
# 278                    Nina Simone  2.10451e+06
# 311                         Bonobo  2.08476e+06
# 526              Ike & Tina Turner       121994
# 489                  Joni Mitchell       520369
# 451                  Joni Mitchell  1.05808e+06
# 2909      EsbjÌÄå¦rn Svensson Trio       160449
# 292                    Nina Simone  1.95419e+06
# 191               Dinah Washington       201038
# 198                    Count Basie       126229
# 334                         Bonobo  1.56357e+06
# 595                     Jill Scott  1.09961e+06
# 188               Dinah Washington       194553
# 616               Michael McDonald       137178
# 520              Ike & Tina Turner       107207
# 295                    Nina Simone  1.90408e+06
# 2485                    Mr. Scruff       196342
# 483                  Joni Mitchell       711171
# 144                   Tony Bennett       453898
# 510                 Herbie Hancock       444177
# 3161                     Morcheeba       742280
# 2257            Harry Connick, Jr.      93716.2
# 219                 Duke Ellington       166304

# %% [markdown]
# Our Pop playlist is as follows:

# %%
df = pd.read_csv("total_info.csv", encoding = 'latin')
del df['Unnamed: 0']

desired_genre = 'pop'
df = df[df['artist_genres'].str.contains(desired_genre)]
df.head()

unique_songs = df['song_name'].unique()
columns = ['song_name','artist_name','score']
score_frame = pd.DataFrame(index=range(0,len(unique_songs)), columns=columns)
for idx,song in enumerate(unique_songs):
    try:
        score_frame.loc[idx]['song_name'] = song
        score_frame.loc[idx]['artist_name'] = df.loc[df['song_name'] == song]['artist_name'].iloc[0]
        this_artist = df.loc[df['song_name'] == song]['artist_name'].iloc[0]
        this_popularity = df.loc[df['song_name'] == song]['popularity'].iloc[0]
        this_explicit = df.loc[df['song_name'] == song]['explicit'].iloc[0]
        this_art_followers = df.loc[df['song_name'] == song]['artist_followers'].iloc[0]
        score_frame.loc[idx]['score'] = song_score(this_artist, this_popularity, this_explicit, this_art_followers)
    except:
        score_frame.loc[idx]['score'] = 0
        pass
    
score_frame.sort_values('score', ascending = False)
threshold = score_frame['score'].quantile(q = 0.75)
top_songs = score_frame[score_frame['score'] >= threshold]
curated_playlist = top_songs.sample(50)
curated_playlist
# Out:
#                                                song_name          artist_name  \
# 6155                               Welcome to the Family    Avenged Sevenfold
# 963                                  Nothing Without You           The Weeknd
# 7219                                         Unbreakable        Of Mice & Men
# 5134                                       Dirty Laundry           Nickelback
# 8850                                U + Me (Love Lesson)        Mary J. Blige
# 7117                                    Painting Flowers         All Time Low
# 3324   Young, Wild & Free (feat. Bruno Mars) - feat. ...           Snoop Dogg
# 599                                            New Flame          Chris Brown
# 8326                          Ain't Nobody Takin My Baby                 Russ
# 3266                                            Untitled            blink-182
# 887                           Reconsider (Jamie xx Edit)               The xx
# 7868                                   Giving Up The Gun      Vampire Weekend
# 417                                   Back from the Edge         James Arthur
# 879                                            Dangerous               The xx
# 5195                                               Magic             Coldplay
# 1015                                     Break From Love           Trey Songz
# 1494                       Fire and the Flood - Acoustic            Vance Joy
# 1540                                      Echoes Of Love          Jesse & Joy
# 9128                                Exhale - Shoop Shoop      Whitney Houston
# 4404                                  I Hope You Find It          Miley Cyrus
# 2914                                         Don't Panic       French Montana
# 252                                     Drowning Shadows            Sam Smith
# 1798                                  Such Great Heights          Iron & Wine
# 9161                                               Cleva          Erykah Badu
# 8571                                     Family Business           Kanye West
# 3314                                      Nobody Told Me                B.o.B
# 6200                                       Beautiful War        Kings of Leon
# 2590                                               Drive               R.E.M.
# 8274                                           Terrified     Childish Gambino
# 3897                                    Scared of Lonely           BeyoncÌÄå©
# 4257                                Simple Twist of Fate            Bob Dylan
# 7021                                               Sloom  Of Monsters and Men
# 304    Lonely Together - (feat. Rita Ora) Dj Licious ...               Avicii
# 16963                                          Love Sosa           Chief Keef
# 8564                                         Gold Digger           Kanye West
# 4593                                       So Many Tears                 2Pac
# 573                                                Three               Future
# 710                                       XXX. FEAT. U2.       Kendrick Lamar
# 276                                         Nothing Left                 Kygo
# 4870                                        It Takes Two           Katy Perry
# 8814                                           Brand New    Pharrell Williams
# 1274                                               Loser                 Beck
# 2731                  Christmas Time Is In The Air Again         Mariah Carey
# 5041                                           Beautiful   Christina Aguilera
# 2775                             iSpy (feat. Lil Yachty)                 KYLE
# 3328                 Gin And Juice (feat. Dat Nigga Daz)           Snoop Dogg
# 8546                           Bad - Remix feat. Rihanna                 Wale
# 6156                                Beast and the Harlot    Avenged Sevenfold
# 8137   You And Tequila (With Grace Potter) (Live At R...        Kenny Chesney
# 4703                                          Unfaithful              Rihanna
#
#              score
# 6155   7.08221e+06
# 963    3.33288e+07
# 7219   2.03897e+06
# 5134   7.09069e+06
# 8850   3.10169e+06
# 7117   3.44235e+06
# 3324   1.12672e+07
# 599    2.18317e+07
# 8326   4.25502e+06
# 3266   7.58641e+06
# 887    8.00504e+06
# 7868    2.8704e+06
# 417    4.97943e+06
# 879    1.00455e+07
# 5195   3.98666e+07
# 1015   8.27441e+06
# 1494   2.63853e+06
# 1540   4.21527e+06
# 9128   4.86459e+06
# 4404   9.77481e+06
# 2914   3.24564e+06
# 252    2.78856e+06
# 1798   1.87611e+06
# 9161   2.03986e+06
# 8571   1.73254e+07
# 3314   2.43499e+06
# 6200   8.88857e+06
# 2590   2.35473e+06
# 8274   8.70182e+06
# 3897   2.92918e+07
# 4257   5.84436e+06
# 7021      5.43e+06
# 304    1.73326e+07
# 16963  2.60406e+06
# 8564   2.58114e+07
# 4593   1.02681e+07
# 573    2.04974e+07
# 710    2.80441e+07
# 276    8.39098e+06
# 4870   2.05732e+07
# 8814   5.60257e+06
# 1274   2.66465e+06
# 2731   4.54045e+06
# 5041   8.38635e+06
# 2775   1.94756e+06
# 3328   1.21208e+07
# 8546   3.40864e+06
# 6156   6.44798e+06
# 8137   3.15612e+06
# 4703   6.29086e+07
